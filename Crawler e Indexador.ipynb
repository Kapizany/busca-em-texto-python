# %% [markdown]
# # Crawler em python e mysql

# %% [raw]
# Construção de um Crawler em Python com persistência de dados em mysql.
#
# As queries ultilizadas para criação das tabelas estão na pasta desse arquivo.

# %% [markdown]
# ## Importações e configurações

# %%
import urllib3
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import MySQLdb
import configparser
import nltk
import re

# %%
def connect():
        config = configparser.ConfigParser()
        config.read('config.ini')
        user = config['DATABASE']['user']
        passwd = config['DATABASE']['passwd']
        db = config['DATABASE']['db']
        host = config['DATABASE']['host']
        port = int(config['DATABASE']['port'])
        autocommit = bool(config['DATABASE']['autocommit'])
        connection = MySQLdb.connect(user=user, passwd=passwd, db=db,
                     host=host, port=port, autocommit=autocommit)
        return connection

# %% [markdown]
# ## Funções de Preprocessamento do Texto

# %%
def stemmer(corpus):
    stem = nltk.stem.RSLPStemmer()
    return [stem.stem(word) for word in corpus]

# %%
def removeTags(sopa):
    for tags in sopa(['script', 'style']):
        tags.decompose()
    return ' '.join(sopa.stripped_strings)

# %%
def createCorpus(doc):
    stop = nltk.corpus.stopwords.words('portuguese')
    stop.append('é')
    pattern = re.compile('\\w+')
    corpus = []
    lista = [p for p in pattern.findall(doc) if p != '']
    for p in lista:
        if p.lower() not in stop:
            if len(p) > 1:
                corpus.append(p.lower())
    return stemmer(corpus)

# %% [markdown]
# ## Funções de Verificação

# %%
def isWordIndexed(palavra):
    connection = connect()
    cursor = connection.cursor()
    cursor.execute(f'''select idpalavra from palavras where palavra = "{palavra}"''')
    wordId = cursor.fetchone()
    if not wordId: # This word isn't in database
        cursor.close()
        connection.close()
        return 0
    
    cursor.close()
    connection.close()
    return wordId[0]

# %%
def isPageIndexed(url):
    connection = connect()
    cursor = connection.cursor()
    query = f'select idurl from urls where url = "{url}"'
    cursor.execute(query)
    idurl = cursor.fetchone()
    # url is not in the database
    if not idurl:
        connection.close()
        return -1
    
    idurl = idurl[0]
    query = f'select idurl from palavra_localizacao where idurl = {idurl}'
    cursor.execute(query)
    thereWordInUrl = cursor.fetchone()
    if not thereWordInUrl:
        # url is in the database but there isn't any word there.
        connection.close()
        return idurl
    connection.close()
    ## url is in the database
    print(thereWordInUrl,idurl)
    return -2

# %% [markdown]
# ## Funções de Inserção

# %%
def insertUrl(url):
    connection = connect()
    cursor = connection.cursor()
    cursor.execute(f'insert into urls (url) values ("{url}")')
    pageId = cursor.lastrowid
    cursor.close()
    connection.close()
    return pageId

# %%
def insertWord(palavra):
    connection = connect()
    cursor = connection.cursor()
    cursor.execute(f'insert into palavras (palavra) values ("{palavra}")')
    wordId = cursor.lastrowid
    cursor.close()
    connection.close()
    return wordId

# %%
def insertWordLocalization(idurl,idpalavra, localization):
    connection = connect()
    cursor = connection.cursor()
    cursor.execute(f'''
        insert into palavra_localizacao (idurl, idpalavra, localizacao) 
                values ({idurl},{idpalavra}, {localization})
    ''')
    localizationId = cursor.lastrowid
    cursor.close()
    connection.close()
    return localizationId

# %%
def insertPage(url, soup):
    urlId = isPageIndexed(url)
    if urlId == -2:
        return 0
    if urlId == -1:
        urlId = insertUrl(url)
    
    doc = removeTags(soup)
    corpus = createCorpus(doc)
    
    for idx,word in enumerate(corpus):
        try:
            wordId = isWordIndexed(word)
            if not wordId:
                wordId = insertWord(word)
            insertWordLocalization(urlId,wordId, idx+1)
        except:
            continue

# %% [markdown]
# ## Crawler para obteção dos links

# %%
def crawl(paginas, profundidade):
    #profundidade é o numero de vezes + 1 que o crawler vai iterar sobre os links obtidos
    urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
    for i in range(profundidade):
        novas_paginas = set(paginas)
        for pagina in paginas:
            http = urllib3.PoolManager()
            try:
                dados_pagina = http.request('GET', pagina)
            except:
                print(f"Erro ao abrir a página {pagina}")
                continue
            sopa = BeautifulSoup(dados_pagina.data, "lxml")
            links = sopa.find_all('a')
            for link in links:
                #print(str(link.contents) + ' - ' + str(link.get('href')))
                if('href' in link.attrs):
                    url = urljoin(pagina, str(link.get('href')))
                    if(url.find("''") != -1):
                        continue
                    url = url.split("#")[0]
                    if url[0:4] == 'http':
                        novas_paginas.add(url)
        paginas = novas_paginas
    return novas_paginas

# %% [markdown]
# ## Função para popular o banco com os dados das páginas

# %%
def populate(urlList):
    urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
    for url in urlList:
        http = urllib3.PoolManager()
        try:
            urlData = http.request('GET', url)
        except:
            print(f"Erro ao abrir a página {url}")
            continue
        soup = BeautifulSoup(urlData.data, "lxml")
        insertPage(url,soup)

# %% [markdown]
# ## Teste com Wikipedia

# %%
lista_paginas = ['https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o']
paginas = crawl(lista_paginas, 1)

# %%
paginas
# Out:
# {'http://books.google.com/books?&as_brr=0&as_epq=Linguagem+de+programa%C3%A7%C3%A3o',
#  'http://dlang.org/overview.html',
#  'http://www.acm.uiuc.edu/signet/JHSI/cr.D.3.2.html',
#  'http://www.cis.gvsu.edu/~kurmasz/Teaching/OldCourses/CS451/CS451_W08/WebPage/Labs/Lab5/index.html',
#  'http://www.infoescola.com/engenharia-de-software/linguagem-de-programacao-de-alto-nivel/',
#  'http://www.levenez.com/lang/history.html',
#  'http://www.scriptol.com/programming/languages.php',
#  'http://www.wired.com/2014/07/d-programming-language/',
#  'https://af.wikipedia.org/wiki/Programmeertaal',
#  'https://als.wikipedia.org/wiki/Programmiersprache',
#  'https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8D%95%E1%88%AE%E1%8C%8D%E1%88%AB%E1%88%9D_%E1%89%8B%E1%8A%95%E1%89%8B',
#  'https://an.wikipedia.org/wiki/Luengache_de_programaci%C3%B3n',
#  'https://ar.wikipedia.org/wiki/%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D8%A9',
#  'https://arz.wikipedia.org/wiki/%D9%84%D8%BA%D8%A9_%D8%A8%D8%B1%D9%85%D8%AC%D9%87',
#  'https://as.wikipedia.org/wiki/%E0%A6%AA%E0%A7%8D%E0%A7%B0%E0%A6%97%E0%A7%8D%E0%A7%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE',
#  'https://ast.wikipedia.org/wiki/Llinguaxe_de_programaci%C3%B3n',
#  'https://az.wikipedia.org/wiki/Proqramla%C5%9Fd%C4%B1rma_dill%C9%99ri',
#  'https://azb.wikipedia.org/wiki/%DB%8C%D8%A7%D8%B2%DB%8C%D9%84%DB%8C%D9%85%D9%84%D8%A7%D9%85%D8%A7_%D8%AF%DB%8C%D9%84%DB%8C',
#  'https://ba.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D0%B5%D0%BB%D0%B5',
#  'https://bar.wikipedia.org/wiki/Programmiasproch',
#  'https://bat-smg.wikipedia.org/wiki/Pruogramav%C4%97ma_kalba',
#  'https://be-tarask.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D1%8C%D0%BD%D1%8F',
#  'https://be.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%B0%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F',
#  'https://bg.wikipedia.org/wiki/%D0%95%D0%B7%D0%B8%D0%BA_%D0%B7%D0%B0_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%B8%D1%80%D0%B0%D0%BD%D0%B5',
#  'https://bh.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%82%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A7%8B%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%BE%E0%A6%AE%E0%A6%BF%E0%A6%82_%E0%A6%AD%E0%A6%BE%E0%A6%B7%E0%A6%BE',
#  'https://br.wikipedia.org/wiki/Lavar_programmi%C3%B1',
#  'https://bs.wikipedia.org/wiki/Programski_jezik',
#  'https://bug.wikipedia.org/wiki/%E1%A8%85%E1%A8%94_%E1%A8%80%E1%A8%9A%E1%A8%87%E1%A8%98%E1%A8%88%E1%A8%9B%E1%A8%91%E1%A8%9B',
#  'https://ca.wikipedia.org/wiki/Llenguatge_de_programaci%C3%B3',
#  'https://cdo.wikipedia.org/wiki/Pi%C4%95ng-ti%C3%A0ng_ng%E1%B9%B3%CC%84-ngi%C3%B2ng',
#  'https://ckb.wikipedia.org/wiki/%D8%B2%D9%85%D8%A7%D9%86%DB%8C_%D8%A8%DB%95%D8%B1%D9%86%D8%A7%D9%85%DB%95%D8%B3%D8%A7%D8%B2%DB%8C',
#  'https://commons.wikimedia.org/wiki/Category:Programming_languages',
#  'https://creativecommons.org/licenses/by-sa/3.0/deed.pt',
#  'https://cs.wikipedia.org/wiki/Programovac%C3%AD_jazyk',
#  'https://cv.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0_%D1%87%C4%95%D0%BB%D1%85%D0%B8',
#  'https://cy.wikipedia.org/wiki/Iaith_rhaglennu',
#  'https://da.wikipedia.org/wiki/Programmeringssprog',
#  'https://de.wikipedia.org/wiki/Programmiersprache',
#  'https://diq.wikipedia.org/wiki/Z%C4%B1wan%C3%AA_programnay%C4%B1%C5%9Fi',
#  'https://dmoztools.net/Computers/Programming/Languages',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=20120521SB001&uselang=pt',
#  'https://el.wikipedia.org/wiki/%CE%93%CE%BB%CF%8E%CF%83%CF%83%CE%B1_%CF%80%CF%81%CE%BF%CE%B3%CF%81%CE%B1%CE%BC%CE%BC%CE%B1%CF%84%CE%B9%CF%83%CE%BC%CE%BF%CF%8D',
#  'https://en.wikipedia.org/wiki/Programming_language',
#  'https://eo.wikipedia.org/wiki/Programlingvo',
#  'https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n',
#  'https://et.wikipedia.org/wiki/Programmeerimiskeel',
#  'https://eu.wikipedia.org/wiki/Programazio-lengoaia',
#  'https://fa.wikipedia.org/wiki/%D8%B2%D8%A8%D8%A7%D9%86_%D8%A8%D8%B1%D9%86%D8%A7%D9%85%D9%87%E2%80%8C%D9%86%D9%88%DB%8C%D8%B3%DB%8C',
#  'https://fi.wikipedia.org/wiki/Ohjelmointikieli',
#  'https://fj.wikipedia.org/wiki/Vosa_parokaramu',
#  'https://foundation.wikimedia.org/wiki/Condições_de_Uso',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://fr.wikipedia.org/wiki/Langage_de_programmation',
#  'https://frr.wikipedia.org/wiki/Programiarspriak',
#  'https://ga.wikipedia.org/wiki/Teanga_r%C3%ADomhchl%C3%A1r%C3%BAch%C3%A1in',
#  'https://gl.wikipedia.org/wiki/Linguaxe_de_programaci%C3%B3n',
#  'https://he.wikipedia.org/wiki/%D7%A9%D7%A4%D7%AA_%D7%AA%D7%9B%D7%A0%D7%95%D7%AA',
#  'https://hi.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%BE%E0%A4%AE%E0%A4%BF%E0%A4%82%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE',
#  'https://hr.wikipedia.org/wiki/Programski_jezik',
#  'https://hsb.wikipedia.org/wiki/Program%C4%9Browanske_r%C4%9B%C4%8De',
#  'https://hu.wikipedia.org/wiki/Programoz%C3%A1si_nyelv',
#  'https://hy.wikipedia.org/wiki/%D4%BE%D6%80%D5%A1%D5%A3%D6%80%D5%A1%D5%BE%D5%B8%D6%80%D5%B4%D5%A1%D5%B6_%D5%AC%D5%A5%D5%A6%D5%B8%D6%82',
#  'https://ia.wikipedia.org/wiki/Linguage_de_programmation',
#  'https://id.wikipedia.org/wiki/Bahasa_pemrograman',
#  'https://ie.wikipedia.org/wiki/Lingue_de_programmation',
#  'https://ilo.wikipedia.org/wiki/Lengguahe_ti_panangprograma',
#  'https://io.wikipedia.org/wiki/Programifo-lingui',
#  'https://is.wikipedia.org/wiki/Forritunarm%C3%A1l',
#  'https://it.wikipedia.org/wiki/Linguaggio_di_programmazione',
#  'https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E8%A8%80%E8%AA%9E',
#  'https://jbo.wikipedia.org/wiki/samplabau',
#  'https://jv.wikipedia.org/wiki/Basa_pamrograman',
#  'https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%94%E1%83%91%E1%83%98%E1%83%A1_%E1%83%94%E1%83%9C%E1%83%90',
#  'https://kab.wikipedia.org/wiki/Tutlayt_n_usihel',
#  'https://kk.wikipedia.org/wiki/%D0%91%D0%B0%D2%93%D0%B4%D0%B0%D1%80%D0%BB%D0%B0%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D1%96%D0%BB%D1%96',
#  'https://km.wikipedia.org/wiki/%E1%9E%97%E1%9E%B6%E1%9E%9F%E1%9E%B6%E1%9E%80%E1%9E%98%E1%9F%92%E1%9E%98%E1%9E%9C%E1%9E%B7%E1%9E%92%E1%9E%B8',
#  'https://ko.wikipedia.org/wiki/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_%EC%96%B8%EC%96%B4',
#  'https://ku.wikipedia.org/wiki/Ziman%C3%AA_bernamekirin%C3%AA',
#  'https://ky.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%BE%D0%BE_%D1%82%D0%B8%D0%BB%D0%B8',
#  'https://la.wikipedia.org/wiki/Lingua_programmandi',
#  'https://lb.wikipedia.org/wiki/Programm%C3%A9iersprooch',
#  'https://lmo.wikipedia.org/wiki/Lenguagg_de_programmazion',
#  'https://lt.wikipedia.org/wiki/Programavimo_kalba',
#  'https://lv.wikipedia.org/wiki/Programm%C4%93%C5%A1anas_valoda',
#  'https://meta.wikimedia.org/wiki/Privacy_policy/pt-br',
#  'https://mhr.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%BB%D1%8B%D0%BC%D0%B0%D1%88_%D0%B9%D1%8B%D0%BB%D0%BC%D0%B5',
#  'https://mk.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B0%D0%B7%D0%B8%D0%BA',
#  'https://ml.wikipedia.org/wiki/%E0%B4%AA%E0%B5%8D%E0%B4%B0%E0%B5%8B%E0%B4%97%E0%B5%8D%E0%B4%B0%E0%B4%BE%E0%B4%AE%E0%B4%BF%E0%B4%82%E0%B4%97%E0%B5%8D_%E0%B4%AD%E0%B4%BE%E0%B4%B7',
#  'https://mn.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D1%87%D0%BB%D0%B0%D0%BB%D1%8B%D0%BD_%D1%85%D1%8D%D0%BB',
#  'https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A5%8B%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A5%85%E0%A4%AE%E0%A4%BF%E0%A4%82%E0%A4%97_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE',
#  'https://ms.wikipedia.org/wiki/Bahasa_pengaturcaraan',
#  'https://mwl.wikipedia.org/wiki/Lenguaige_de_porgrama%C3%A7on',
#  'https://my.wikipedia.org/wiki/Programming_language',
#  'https://nds.wikipedia.org/wiki/Programmeerspraak',
#  'https://ne.wikipedia.org/wiki/%E0%A4%95%E0%A4%AE%E0%A5%8D%E0%A4%AA%E0%A5%8D%E0%A4%AF%E0%A5%81%E0%A4%9F%E0%A4%B0_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE',
#  'https://nl.wikipedia.org/wiki/Programmeertaal',
#  'https://nn.wikipedia.org/wiki/Programmeringsspr%C3%A5k',
#  'https://no.wikipedia.org/wiki/Programmeringsspr%C3%A5k',
#  'https://nqo.wikipedia.org/wiki/%DF%A2%DF%8D%DF%A5%DF%9F%DF%8A%DF%A6%DF%8A%DF%9F%DF%8C%DF%AB_%DF%9E%DF%8A%DF%B2',
#  'https://oc.wikipedia.org/wiki/Lengatge_de_programacion',
#  'https://pa.wikipedia.org/wiki/%E0%A8%AA%E0%A9%8D%E0%A8%B0%E0%A9%8B%E0%A8%97%E0%A8%B0%E0%A8%BE%E0%A8%AE%E0%A8%BF%E0%A9%B0%E0%A8%97_%E0%A8%AD%E0%A8%BE%E0%A8%B8%E0%A8%BC%E0%A8%BE',
#  'https://pl.wikipedia.org/wiki/J%C4%99zyk_programowania',
#  'https://pms.wikipedia.org/wiki/Lengage_%C3%ABd_programassion',
#  'https://pnb.wikipedia.org/wiki/%DA%A9%D9%85%D9%BE%DB%8C%D9%88%D9%B9%D8%B1_%D8%A8%D9%88%D9%84%DB%8C',
#  'https://ps.wikipedia.org/wiki/%D8%A8%D8%B1%D9%8A%D8%B4%D9%84%D9%8A%DA%A9_%DA%98%D8%A8%D9%87',
#  'https://pt.m.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&mobileaction=toggle_view_mobile',
#  'https://pt.wikipedia.org/w/index.php?title=Especial:Citar&page=Linguagem_de_programa%C3%A7%C3%A3o&id=59464915&wpFormIdentifier=titleform',
#  'https://pt.wikipedia.org/w/index.php?title=Especial:Criar_conta&returnto=Linguagem+de+programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/w/index.php?title=Especial:DownloadAsPdf&page=Linguagem_de_programa%C3%A7%C3%A3o&action=show-download-screen',
#  'https://pt.wikipedia.org/w/index.php?title=Especial:Entrar&returnto=Linguagem+de+programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/w/index.php?title=Especial:Livro&bookcmd=book_creator&referer=Linguagem+de+programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&action=edit',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&action=history',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&action=info',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&oldid=59464915',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programa%C3%A7%C3%A3o&printable=yes',
#  'https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programação&oldid=59464915',
#  'https://pt.wikipedia.org/w/index.php?title=Predefini%C3%A7%C3%A3o:Linguagens_de_programa%C3%A7%C3%A3o&action=edit',
#  'https://pt.wikipedia.org/wiki/%C3%8Dndice_Tiobe',
#  'https://pt.wikipedia.org/wiki/1840',
#  'https://pt.wikipedia.org/wiki/1958',
#  'https://pt.wikipedia.org/wiki/1984',
#  'https://pt.wikipedia.org/wiki/2005',
#  'https://pt.wikipedia.org/wiki/ALGOL',
#  'https://pt.wikipedia.org/wiki/APL',
#  'https://pt.wikipedia.org/wiki/ASP',
#  'https://pt.wikipedia.org/wiki/Abstra%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Abstra%C3%A7%C3%A3o_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/ActionScript',
#  'https://pt.wikipedia.org/wiki/Ada_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Ada_Lovelace',
#  'https://pt.wikipedia.org/wiki/Ajuda:Erros_nas_refer%C3%AAncias',
#  'https://pt.wikipedia.org/wiki/Ajuda:Guia_de_edi%C3%A7%C3%A3o/Como_come%C3%A7ar_uma_p%C3%A1gina',
#  'https://pt.wikipedia.org/wiki/Ajuda:P%C3%A1gina_principal',
#  'https://pt.wikipedia.org/wiki/Alemanha_Nazista',
#  'https://pt.wikipedia.org/wiki/Alfred_Aho',
#  'https://pt.wikipedia.org/wiki/Alfred_Edward_Chalon',
#  'https://pt.wikipedia.org/wiki/Algol_60',
#  'https://pt.wikipedia.org/wiki/Algoritmo',
#  'https://pt.wikipedia.org/wiki/Algoritmo_de_Trabb_Pardo-Knuth',
#  'https://pt.wikipedia.org/wiki/An%C3%A1lise_l%C3%A9xica',
#  'https://pt.wikipedia.org/wiki/An%C3%A1lise_sint%C3%A1tica',
#  'https://pt.wikipedia.org/wiki/Assembly',
#  'https://pt.wikipedia.org/wiki/Association_for_Computing_Machinery',
#  'https://pt.wikipedia.org/wiki/Atributo_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Awk',
#  'https://pt.wikipedia.org/wiki/B-0',
#  'https://pt.wikipedia.org/wiki/BASIC',
#  'https://pt.wikipedia.org/wiki/Basic',
#  'https://pt.wikipedia.org/wiki/C%2B%2B',
#  'https://pt.wikipedia.org/wiki/C%C3%B3digo_de_m%C3%A1quina',
#  'https://pt.wikipedia.org/wiki/C%C3%B3digo_fonte',
#  'https://pt.wikipedia.org/wiki/COBOL',
#  'https://pt.wikipedia.org/wiki/C_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/C_Sharp',
#  'https://pt.wikipedia.org/wiki/Categoria:!Artigos_que_carecem_de_notas_de_rodap%C3%A9_desde_setembro_de_2020',
#  'https://pt.wikipedia.org/wiki/Categoria:!Artigos_que_carecem_de_notas_de_rodap%C3%A9_sem_indica%C3%A7%C3%A3o_de_tema',
#  'https://pt.wikipedia.org/wiki/Categoria:!CS1_ingl%C3%AAs-fontes_em_l%C3%ADngua_(en)',
#  'https://pt.wikipedia.org/wiki/Categoria:!CS1_manut:_L%C3%ADngua_n%C3%A3o_reconhecida',
#  'https://pt.wikipedia.org/wiki/Categoria:!CS1_manut:_Nomes_m%C3%BAltiplos:_lista_de_autores',
#  'https://pt.wikipedia.org/wiki/Categoria:!P%C3%A1ginas_com_erros_CS1:_caracteres_invis%C3%ADveis',
#  'https://pt.wikipedia.org/wiki/Categoria:!P%C3%A1ginas_com_refer%C3%AAncias_com_par%C3%A2metros_indefinidos',
#  'https://pt.wikipedia.org/wiki/Categoria:!P%C3%A1ginas_que_usam_refer%C3%AAncias_com_par%C3%A2metros_obsoletas',
#  'https://pt.wikipedia.org/wiki/Categoria:Linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Categoria:T%C3%B3picos_em_linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Charles_Babbage',
#  'https://pt.wikipedia.org/wiki/Ci%C3%AAncia_da_computa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Classe_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Common_Language_Infrastructure',
#  'https://pt.wikipedia.org/wiki/Compara%C3%A7%C3%A3o_entre_linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Compilador',
#  'https://pt.wikipedia.org/wiki/Computa%C3%A7%C3%A3o_distribu%C3%ADda',
#  'https://pt.wikipedia.org/wiki/Computa%C3%A7%C3%A3o_paralela',
#  'https://pt.wikipedia.org/wiki/Computador',
#  'https://pt.wikipedia.org/wiki/Cond%C3%A9_Nast_Publications',
#  'https://pt.wikipedia.org/wiki/DMOZ',
#  'https://pt.wikipedia.org/wiki/D_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Dart_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Discuss%C3%A3o:Linguagem_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Editor_hexadecimal',
#  'https://pt.wikipedia.org/wiki/Elixir_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Engenharia_de_software',
#  'https://pt.wikipedia.org/wiki/Erlang_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Especial:Aleat%C3%B3ria',
#  'https://pt.wikipedia.org/wiki/Especial:Altera%C3%A7%C3%B5es_relacionadas/Linguagem_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Especial:Categorias',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-000484-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-005315-4',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-213084-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-238111-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-882476-1',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-07-911725-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-12-200550-3',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-12-491650-3',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-12-528260-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-12-745040-8',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-027678-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-035155-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-062296-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-215871-X',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-371345-8',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-454646-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-596404-0',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-630740-X',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-728866-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-13-729988-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-19-511306-3',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-00022-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-13688-0',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-30972-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-39815-X',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-59065-4',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-201-63179-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-262-06145-7',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-262-13011-4',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-442-20920-7',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-471-10426-4',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-521-64408-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-534-94740-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-596-00085-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-596-00309-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-8053-1191-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-8493-7341-7',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-85312-709-3',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0-88175-142-1',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/0201-40375-7',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/088175-004-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/1-55860-698-X',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/1-57586-382-0',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/1-934356-08-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-212-0322-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-216-0283-9',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-216-0658-3',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-7001-342-6',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-7001-420-1',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/85-7139-021-5',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/978-0-12-633951-2',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/978-85-7780-791-8',
#  'https://pt.wikipedia.org/wiki/Especial:Fontes_de_livros/978-85-88639-24-9',
#  'https://pt.wikipedia.org/wiki/Especial:Minha_discuss%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Especial:Minhas_contribui%C3%A7%C3%B5es',
#  'https://pt.wikipedia.org/wiki/Especial:Mudan%C3%A7as_recentes',
#  'https://pt.wikipedia.org/wiki/Especial:P%C3%A1ginas_afluentes/Linguagem_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Especial:P%C3%A1ginas_especiais',
#  'https://pt.wikipedia.org/wiki/Especial:P%C3%A1ginas_novas',
#  'https://pt.wikipedia.org/wiki/Euphoria_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Ada_Lovelace_portrait.jpg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:DeCSS.PNG',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Folder_Hexagonal_Icon.svg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Grace_Hopper.jpg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Niklaus_Wirth,_UrGU.jpg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Nt-compilador.png',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Programming_language_textbooks.jpg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Question_book-new.svg',
#  'https://pt.wikipedia.org/wiki/Ficheiro:Symbol_list_class.svg',
#  'https://pt.wikipedia.org/wiki/Flow-Matic',
#  'https://pt.wikipedia.org/wiki/Fortran',
#  'https://pt.wikipedia.org/wiki/G%C3%B6del_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Gera%C3%A7%C3%A3o_de_c%C3%B3digo',
#  'https://pt.wikipedia.org/wiki/Go_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Goto_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Grace_Hopper',
#  'https://pt.wikipedia.org/wiki/Haskell_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Haskell_Curry',
#  'https://pt.wikipedia.org/wiki/Heran%C3%A7a_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Hist%C3%B3ria_das_linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_Artificial',
#  'https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial',
#  'https://pt.wikipedia.org/wiki/International_Standard_Book_Number',
#  'https://pt.wikipedia.org/wiki/International_Standard_Serial_Number',
#  'https://pt.wikipedia.org/wiki/Interpretadores',
#  'https://pt.wikipedia.org/wiki/JIT',
#  'https://pt.wikipedia.org/wiki/JavaScript',
#  'https://pt.wikipedia.org/wiki/Java_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Julia_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Konrad_Zuse',
#  'https://pt.wikipedia.org/wiki/Kotlin',
#  'https://pt.wikipedia.org/wiki/Larry_Gonick',
#  'https://pt.wikipedia.org/wiki/Linguagem_assembly',
#  'https://pt.wikipedia.org/wiki/Linguagem_compilada',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_Programa%C3%A7%C3%A3o_Combinada',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_Java',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_de_alto_n%C3%ADvel',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_de_primeira_gera%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_de_quarta_gera%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_de_segunda_gera%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_de_terceira_gera%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_programa%C3%A7%C3%A3o_esot%C3%A9rica',
#  'https://pt.wikipedia.org/wiki/Linguagem_de_script',
#  'https://pt.wikipedia.org/wiki/Linguagem_funcional',
#  'https://pt.wikipedia.org/wiki/Linguagem_humana',
#  'https://pt.wikipedia.org/wiki/Linguagem_interpretada',
#  'https://pt.wikipedia.org/wiki/Lisp',
#  'https://pt.wikipedia.org/wiki/Lista_de_linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Lua_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/M%C3%A1quina_virtual',
#  'https://pt.wikipedia.org/wiki/M%C3%A9todo_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/MATLAB',
#  'https://pt.wikipedia.org/wiki/ML_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Macro',
#  'https://pt.wikipedia.org/wiki/Mensagem_(programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Microprocessador',
#  'https://pt.wikipedia.org/wiki/Modula-2',
#  'https://pt.wikipedia.org/wiki/Modula-3',
#  'https://pt.wikipedia.org/wiki/Montador',
#  'https://pt.wikipedia.org/wiki/New_Jersey',
#  'https://pt.wikipedia.org/wiki/Niklaus_Wirth',
#  'https://pt.wikipedia.org/wiki/Object_Pascal',
#  'https://pt.wikipedia.org/wiki/Objective-C',
#  'https://pt.wikipedia.org/wiki/Objeto_(ci%C3%AAncia_da_computa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Orienta%C3%A7%C3%A3o_a_objetos',
#  'https://pt.wikipedia.org/wiki/Otimiza%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/PHP',
#  'https://pt.wikipedia.org/wiki/PL/SQL',
#  'https://pt.wikipedia.org/wiki/Paradigma_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Parser',
#  'https://pt.wikipedia.org/wiki/Pascal_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Perl',
#  'https://pt.wikipedia.org/wiki/Plankalk%C3%BCl',
#  'https://pt.wikipedia.org/wiki/Plataforma_Java',
#  'https://pt.wikipedia.org/wiki/Portal:%C3%8Dndice',
#  'https://pt.wikipedia.org/wiki/Portal:Conte%C3%BAdo_destacado',
#  'https://pt.wikipedia.org/wiki/Portal:Eventos_atuais',
#  'https://pt.wikipedia.org/wiki/Predefini%C3%A7%C3%A3o:Linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Predefini%C3%A7%C3%A3o_Discuss%C3%A3o:Linguagens_de_programa%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_concorrente',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_de_computadores',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_declarativa',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_estruturada',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_imperativa',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_l%C3%B3gica',
#  'https://pt.wikipedia.org/wiki/Programa%C3%A7%C3%A3o_procedural',
#  'https://pt.wikipedia.org/wiki/Programa_Ol%C3%A1_Mundo',
#  'https://pt.wikipedia.org/wiki/Programa_de_computador',
#  'https://pt.wikipedia.org/wiki/Prolog',
#  'https://pt.wikipedia.org/wiki/Python',
#  'https://pt.wikipedia.org/wiki/Quine_(inform%C3%A1tica)',
#  'https://pt.wikipedia.org/wiki/R_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Rede_neural',
#  'https://pt.wikipedia.org/wiki/Ruby_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Rust_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/SNOBOL_4',
#  'https://pt.wikipedia.org/wiki/SQL',
#  'https://pt.wikipedia.org/wiki/Scala_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/Scheme',
#  'https://pt.wikipedia.org/wiki/Scratch',
#  'https://pt.wikipedia.org/wiki/Shell_script',
#  'https://pt.wikipedia.org/wiki/Simula_67',
#  'https://pt.wikipedia.org/wiki/Sintaxe',
#  'https://pt.wikipedia.org/wiki/Sistema_A-0',
#  'https://pt.wikipedia.org/wiki/Smalltalk',
#  'https://pt.wikipedia.org/wiki/Software',
#  'https://pt.wikipedia.org/wiki/Sub-rotina_aninhada',
#  'https://pt.wikipedia.org/wiki/SuperCollider',
#  'https://pt.wikipedia.org/wiki/Swift_(linguagem_de_programa%C3%A7%C3%A3o)',
#  'https://pt.wikipedia.org/wiki/T%C3%A9rcio_Pacitti',
#  'https://pt.wikipedia.org/wiki/Tcl',
#  'https://pt.wikipedia.org/wiki/Turing_completude',
#  'https://pt.wikipedia.org/wiki/TypeScript',
#  'https://pt.wikipedia.org/wiki/UML',
#  'https://pt.wikipedia.org/wiki/VB.NET',
#  'https://pt.wikipedia.org/wiki/Visual_Basic',
#  'https://pt.wikipedia.org/wiki/Visual_Basic_.NET',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Aviso_geral',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Boas-vindas',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Contato',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Esplanada',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Fontes_confi%C3%A1veis',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Informe_um_erro',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Manuten%C3%A7%C3%A3o',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_de_testes',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Portal_comunit%C3%A1rio',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:REF',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Sobre',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:V',
#  'https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:Verificabilidade',
#  'https://pt.wikipedia.org/wiki/Wikipedia:Carregar_ficheiro',
#  'https://pt.wikipedia.org/wiki/Wired',
#  'https://ro.wikipedia.org/wiki/Limbaj_de_programare',
#  'https://ru.wikipedia.org/wiki/%D0%AF%D0%B7%D1%8B%D0%BA_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F',
#  'https://rue.wikipedia.org/wiki/%D0%AF%D0%B7%D1%8B%D0%BA_%D0%BF%D1%80%D0%BE%D2%91%D1%80%D0%B0%D0%BC%D0%BE%D0%B2%D0%B0%D0%BD%D1%8F',
#  'https://sah.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D0%B0h%D1%8B%D0%BD_%D1%82%D1%8B%D0%BB%D0%B0',
#  'https://sc.wikipedia.org/wiki/Limb%C3%A0giu_de_programmatzione',
#  'https://scholar.google.com.br/scholar?hl=pt&q=Linguagem+de+programa%C3%A7%C3%A3o',
#  'https://sco.wikipedia.org/wiki/Programmin_leid',
#  'https://sh.wikipedia.org/wiki/Programski_jezik',
#  'https://shn.wikipedia.org/wiki/Programming_language',
#  'https://shop.wikimedia.org',
#  'https://si.wikipedia.org/wiki/%E0%B6%9A%E0%B7%8A%E2%80%8D%E0%B6%BB%E0%B6%B8%E0%B6%BD%E0%B7%9A%E0%B6%9B%E0%B6%B1_%E0%B6%B7%E0%B7%8F%E0%B7%82%E0%B7%8F%E0%B7%80',
#  'https://simple.wikipedia.org/wiki/Programming_language',
#  'https://sk.wikipedia.org/wiki/Programovac%C3%AD_jazyk',
#  'https://sl.wikipedia.org/wiki/Programski_jezik',
#  'https://sq.wikipedia.org/wiki/Gjuh%C3%AB_programimi',
#  'https://sr.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%81%D0%BA%D0%B8_%D1%98%D0%B5%D0%B7%D0%B8%D0%BA',
#  'https://stats.wikimedia.org/',
#  'https://su.wikipedia.org/wiki/Basa_program',
#  'https://sv.wikipedia.org/wiki/Programspr%C3%A5k',
#  'https://sw.wikipedia.org/wiki/Lugha_ya_programu',
#  'https://ta.wikipedia.org/wiki/%E0%AE%A8%E0%AE%BF%E0%AE%B0%E0%AE%B2%E0%AF%8D_%E0%AE%AE%E0%AF%8A%E0%AE%B4%E0%AE%BF',
#  'https://te.wikipedia.org/wiki/%E0%B0%AA%E0%B1%8D%E0%B0%B0%E0%B1%8B%E0%B0%97%E0%B1%8D%E0%B0%B0%E0%B0%BE%E0%B0%AE%E0%B0%BF%E0%B0%82%E0%B0%97%E0%B1%81_%E0%B0%AD%E0%B0%BE%E0%B0%B7',
#  'https://tet.wikipedia.org/wiki/Programing',
#  'https://tg.wikipedia.org/wiki/%D0%97%D0%B0%D0%B1%D0%BE%D0%BD%D0%B8_%D0%B1%D0%B0%D1%80%D0%BD%D0%BE%D0%BC%D0%B0%D0%BD%D0%B0%D0%B2%D0%B8%D1%81%D3%A3',
#  'https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%82%E0%B8%9B%E0%B8%A3%E0%B9%81%E0%B8%81%E0%B8%A3%E0%B8%A1',
#  'https://tl.wikipedia.org/wiki/Wikang_pamprograma',
#  'https://tr.wikipedia.org/wiki/Programlama_dili',
#  'https://tt.wikipedia.org/wiki/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%D0%BB%D0%B0%D1%83_%D1%82%D0%B5%D0%BB%D0%B5',
#  'https://ug.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%85%D8%A7_%D8%AA%D9%89%D9%84%D9%89',
#  'https://uk.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B2%D0%B0_%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D1%83%D0%B2%D0%B0%D0%BD%D0%BD%D1%8F',
#  'https://ur.wikipedia.org/wiki/%D9%BE%D8%B1%D9%88%DA%AF%D8%B1%D8%A7%D9%85%D9%86%DA%AF_%D8%B2%D8%A8%D8%A7%D9%86',
#  'https://uz.wikipedia.org/wiki/Programmalash_tili',
#  'https://vec.wikipedia.org/wiki/Lenguajo_de_programasion',
#  'https://vi.wikipedia.org/wiki/Ng%C3%B4n_ng%E1%BB%AF_l%E1%BA%ADp_tr%C3%ACnh',
#  'https://war.wikipedia.org/wiki/Pinulongan_hin_programa',
#  'https://wikimediafoundation.org/',
#  'https://wuu.wikipedia.org/wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80',
#  'https://www.google.com/',
#  'https://www.google.com/search?hl=pt&tbm=nws&q=Linguagem+de+programa%C3%A7%C3%A3o&oq=Linguagem+de+programa%C3%A7%C3%A3o',
#  'https://www.intel.com/content/www/us/en/architecture-and-technology/64-ia-32-architectures-software-developer-vol-2a-manual.html',
#  'https://www.mediawiki.org/',
#  'https://www.mediawiki.org/wiki/Programming_languages',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://www.techopedia.com/definition/3903/assembly-language',
#  'https://www.tiobe.com/tiobe-index/',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q9143',
#  'https://www.worldcat.org/issn/1058-6180',
#  'https://xmf.wikipedia.org/wiki/%E1%83%9E%E1%83%A0%E1%83%9D%E1%83%92%E1%83%A0%E1%83%90%E1%83%9B%E1%83%98%E1%83%A0%E1%83%90%E1%83%A4%E1%83%90%E1%83%A8_%E1%83%9C%E1%83%98%E1%83%9C%E1%83%90',
#  'https://yi.wikipedia.org/wiki/%D7%A4%D7%A8%D7%90%D7%92%D7%A8%D7%90%D7%9E%D7%99%D7%A8%D7%9F_%D7%A9%D7%A4%D7%A8%D7%90%D7%9A',
#  'https://yo.wikipedia.org/wiki/%C3%88d%C3%A8_%C3%8C%E1%B9%A3%C3%A8l%C3%A0n%C3%A0_K%E1%BB%8D%CC%80mp%C3%BAt%C3%A0',
#  'https://zh-classical.wikipedia.org/wiki/%E7%B7%A8%E7%A8%8B%E8%AA%9E%E8%A8%80',
#  'https://zh-min-nan.wikipedia.org/wiki/Th%C3%AAng-sek_g%C3%AD-gi%C3%A2n',
#  'https://zh-yue.wikipedia.org/wiki/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80',
#  'https://zh.wikipedia.org/wiki/%E7%BC%96%E7%A8%8B%E8%AF%AD%E8%A8%80'}

# %%
populate(paginas)
# Out:
# Erro ao abrir a página http://www.acm.uiuc.edu/signet/JHSI/cr.D.3.2.html
# Erro ao abrir a página https://pt.wikipedia.org/w/index.php?title=Linguagem_de_programação&oldid=59464915
# (129,) 129
# Erro ao abrir a página https://foundation.wikimedia.org/wiki/Condições_de_Uso
